# %%
from utils.load_data import load_data
import pandas as pd
df = load_data('data/commodity_prices.csv')
df.head()
# Out:
#                 Product_Type   Commodity           Variety_Type Arrival_Date  \
# 0  Alsandikai|Alsandikai|FAQ  Alsandikai  Alsandikai|Alsandikai   2023-12-13
# 1  Alsandikai|Alsandikai|FAQ  Alsandikai  Alsandikai|Alsandikai   2023-12-14
# 2  Alsandikai|Alsandikai|FAQ  Alsandikai  Alsandikai|Alsandikai   2023-12-16
# 3  Alsandikai|Alsandikai|FAQ  Alsandikai  Alsandikai|Alsandikai   2023-12-18
# 4  Alsandikai|Alsandikai|FAQ  Alsandikai  Alsandikai|Alsandikai   2023-12-19
#
#           Market  Is_VFPCK  Season  Year  Modal_Price  log_Modal_Price  \
# 0  North Paravur     False  Winter  2023       5200.0         8.556606
# 1  North Paravur     False  Winter  2023       6200.0         8.732466
# 2  North Paravur     False  Winter  2023       4800.0         8.476580
# 3  North Paravur     False  Winter  2023       3500.0         8.160804
# 4  North Paravur     False  Winter  2023       5500.0         8.612685
#
#    Max_Price  Min_Price
# 0     6000.0     5000.0
# 1     6500.0     6000.0
# ...

# %%
df.groupby('Market')['Modal_Price'].mean().sort_values()
# Out:
# Market
# Thiruvaniyoor  VFPCK      2804.354067
# Vengola  VFPCK            2894.972067
# Mazhuvannur VFPCK         2914.550510
# Edackattuvayal  VFPCK     2949.321267
# Koovapadi VFPCK           2985.395929
# Keezhampara VFPCK         3172.676259
# POTHANIKKADU VFPCK        3256.531532
# Amalapuram  VFPCK         3702.689487
# Mookkannur  VFPCK         3703.814714
# Malayattoor  VFPCK        3843.021305
# Ernakulam                 3888.066118
# THURAVOOR VFPCK           3914.175258
# Nedungapra  VFPCK         4077.677541
# Moovattupuzha             4106.572120
# KURUMASSERY VFPCK         4142.465753
# Kothamangalam             4220.398987
# Aluva                     4355.408200
# KARUMALOOR VFPCK          4562.962963
# Broadway market           5102.882191
# Kunnukara  VFPCK          5174.268293
# Kadungallur  VFPCK        5313.111111
# Puthenvelikkara  VFPCK    5338.705584
# Angamaly                  5382.657895
# Piravam                   5514.096089
# ...
