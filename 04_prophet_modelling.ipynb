# %%
import pandas as pd
import numpy as np
import pickle
import optuna
from prophet import Prophet
from sklearn.metrics import root_mean_squared_error, mean_absolute_error
from prophet.diagnostics import cross_validation, performance_metrics
import io
from contextlib import redirect_stdout, redirect_stderr

from utils.load_data import load_data
from utils.data_splitter import DataSplitter

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
optuna.logging.set_verbosity(optuna.logging.WARNING)

df = load_data('data/commodity_prices.csv')

# %%
date_dict = {
    'train_start': "2023-06-01", 'train_end': "2025-06-30",
    'valid_start': "2025-07-01", 'valid_end': "2025-07-31",
    'test_start': "2025-08-01", 'test_end': "2025-08-18"
}

thresholds = {
    'train': 100,
    'valid': 10,
    'test': 5
}

splitter = DataSplitter(df, date_dict, thresholds)
train_df, valid_df, test_df = splitter.run()

# %%
train_df = train_df.rename(columns={
    'Arrival_Date': 'ds',
    'log_Modal_Price': 'y'
})

pairs = train_df[['Product_Type', 'Market']].drop_duplicates()
results = []

for _, row in pairs.iterrows():
    product = row['Product_Type']
    market = row['Market']

    subset = train_df[(train_df['Product_Type'] == product) & (train_df['Market'] == market)]
    prophet_df = subset[['ds', 'y']]

    # Define objective function
    def objective(trial):
        model = Prophet(
            changepoint_prior_scale=trial.suggest_float('changepoint_prior_scale', 0.001, 0.5, log=True),
            seasonality_prior_scale=trial.suggest_float('seasonality_prior_scale', 1, 20, log=True),
            seasonality_mode=trial.suggest_categorical("seasonality_mode", ["additive", "multiplicative"]),
            yearly_seasonality=True,
            weekly_seasonality=False,
            daily_seasonality=False
        )

        # Redirect stdout/stderr to suppress CmdStanPy logs
        f = io.StringIO()
        with redirect_stdout(f), redirect_stderr(f):
            model.fit(prophet_df)

            df_cv = cross_validation(
                model,
                initial='100 days',
                period='90 days',
                horizon='30 days',
                disable_tqdm=True  # disables Prophet CV progress bar
            )

        df_perf = performance_metrics(df_cv)
        return df_perf['rmse'].mean()

    # Run Optuna optimization silently
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=30, show_progress_bar=False, n_jobs=1)

    best_params = study.best_params
    best_rmse = study.best_value

    # Fit final model silently
    f = io.StringIO()
    with redirect_stdout(f), redirect_stderr(f):
        best_model = Prophet(
            **best_params,
            yearly_seasonality=True,
            weekly_seasonality=False,
            daily_seasonality=False
        )
        best_model.fit(prophet_df)

    # Save model
    filename = f"models/prophet/prophet_{product}_{market}.pkl"
    with open(filename, "wb") as f_model:
        pickle.dump(best_model, f_model)

    # Save results
    results.append({
        "Product_Type": product,
        "Market": market,
        "best_params": best_params,
        "best_rmse": best_rmse
    })

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# %%
valid_df = valid_df.rename(columns ={
    'Arrival_Date': 'ds',
    'log_Modal_Price': 'y'
})

val_results = []

pairs = valid_df[['Product_Type', 'Market']].drop_duplicates()

for _, row in pairs.iterrows():
    product = row['Product_Type']
    market = row['Market']

    filename = f"models/prophet/prophet_{product}_{market}.pkl"
    try:
        with open(filename, "rb") as f:
            model = pickle.load(f)
    except FileNotFoundError:
        print(f"Model not found for {product}, {market}, skipping...")
        continue

    subset = valid_df[(valid_df['Product_Type'] == product) & (valid_df['Market'] == market)]
    
    future = model.make_future_dataframe(periods=30)
    forecast = model.predict(future)

    forecast_val = forecast[forecast['ds'].isin(subset['ds'])]
    merged = forecast_val[["ds", "yhat"]].merge(subset[["ds", "y"]], on="ds")

    rmse = root_mean_squared_error(merged["y"], merged["yhat"])
    mae = mean_absolute_error(merged["y"], merged["yhat"])
    mape = np.mean(np.abs((merged["y"] - merged["yhat"]) / merged["y"])) * 100

    val_results.append({
        "Product_Type": product,
        "Market": market,
        "RMSE": rmse,
        "MAE": mae,
        "MAPE": mape
    })

val_results_df = pd.DataFrame(val_results)

# %%
train_df = train_df.rename(columns ={
    'Arrival_Date': 'ds',
    'log_Modal_Price': 'y'
})

pairs = train_df[['Product_Type', 'Market']].drop_duplicates()

results = []

for _, row in pairs.iterrows():
    product = row['Product_Type']
    market = row['Market']

    subset = train_df[(train_df['Product_Type'] == product) & (train_df['Market'] == market)]
    prophet_df = subset[['ds', 'y']]

    # Define objective function inside the loop
    def objective(trial):
        model = Prophet(
            changepoint_prior_scale=trial.suggest_float('changepoint_prior_scale', 0.001, 0.5, log=True),
            seasonality_prior_scale=trial.suggest_float('seasonality_prior_scale', 1, 20, log=True),
            seasonality_mode=trial.suggest_categorical("seasonality_mode", ["additive", "multiplicative"]),
            yearly_seasonality=True,
            weekly_seasonality=False,
            daily_seasonality=False
        )
        model.fit(prophet_df)

        df_cv = cross_validation(
            model,
            initial='365 days',
            period='90 days',
            horizon='30 days',
            disable_tqdm=True
        )
        df_perf = performance_metrics(df_cv)
        return df_perf['rmse'].mean()

    # Run optimization
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=20, show_progress_bar=False, n_jobs=2)  # fewer trials if you have 293 pairs

    best_params = study.best_params
    best_rmse = study.best_value

    # Fit final model with best params
    best_model = Prophet(**best_params, yearly_seasonality=True, weekly_seasonality=False, daily_seasonality=False)
    best_model.fit(prophet_df)

    # Save model
    filename = f"models/prophet/prophet_{product}_{market}.pkl"
    with open(filename, "wb") as f:
        pickle.dump(best_model, f)

    # Save results
    results.append({
        "Product_Type": product,
        "Market": market,
        "best_params": best_params,
        "best_rmse": best_rmse
    })

# Convert results to DataFrame
results_df = pd.DataFrame(results)
# Out:
# 15:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:36 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:36 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:36 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:37 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:38 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:39 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:40 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:41 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:42 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:43 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:50 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:51 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:52 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:49:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] done processing
# 15:49:54 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# ...
# 15:50:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:44 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:45 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:46 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:47 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] start processing
# 15:50:49 - cmdstanpy - INFO - Chain [1] done processing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 41
#      39 # Run optimization
#      40 study = optuna.create_study(direction="minimize")
# ---> 41 study.optimize(objective, n_trials=20, show_progress_bar=False, n_jobs=2)  # fewer trials if you have 293 pairs
#      43 best_params = study.best_params
#      44 best_rmse = study.best_value
#
# File ~/Downloads/projects/commodity_pricing/.venv/lib/python3.10/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)
#     397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/Downloads/projects/commodity_pricing/.venv/lib/python3.10/site-packages/optuna/study/_optimize.py:97, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      94     break
#      96 if len(futures) >= n_jobs:
# ---> 97     completed, futures = wait(futures, return_when=FIRST_COMPLETED)
#      98     # Raise if exception occurred in executing the completed futures.
#      99     for f in completed:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/concurrent/futures/_base.py:307, in wait(fs, timeout, return_when)
#     303         return DoneAndNotDoneFutures(done, not_done)
#     305     waiter = _create_and_install_waiters(fs, return_when)
# --> 307 waiter.event.wait(timeout)
#     308 for f in fs:
#     309     with f._condition:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
valid_df = valid_df.rename(columns ={
    'Arrival_Date': 'ds',
    'log_Modal_Price': 'y'
})

val_results = []

pairs = valid_df[['Product_Type', 'Market']].drop_duplicates()

for _, row in pairs.iterrows():
    product = row['Product_Type']
    market = row['Market']

    filename = f"models/prophet/prophet_{product}_{market}.pkl"
    try:
        with open(filename, "rb") as f:
            model = pickle.load(f)
    except FileNotFoundError:
        print(f"Model not found for {product}, {market}, skipping...")
        continue

    subset = valid_df[(valid_df['Product_Type'] == product) & (valid_df['Market'] == market)]
    
    future = model.make_future_dataframe(periods=30)
    forecast = model.predict(future)

    forecast_val = forecast[forecast['ds'].isin(subset['ds'])]
    merged = forecast_val[["ds", "yhat"]].merge(subset[["ds", "y"]], on="ds")

    rmse = mean_squared_error(merged["y"], merged["yhat"], squared=False)
    mae = mean_absolute_error(merged["y"], merged["yhat"])
    mape = np.mean(np.abs((merged["y"] - merged["yhat"]) / merged["y"])) * 100

    val_results.append({
        "Product_Type": product,
        "Market": market,
        "RMSE": rmse,
        "MAE": mae,
        "MAPE": mape
    })

val_results_df = pd.DataFrame(val_results)

# %%
train_df = train_df.rename(columns ={
    'Arrival_Date': 'ds',
    'log_Modal_Price': 'y'
})
results = []

prophet_df = train_df[['ds', 'y']]


def objective(trial):
    changepoint_prior_scale = trial.suggest_float('changepoint_prior_scale', 0.001, 0.5, log=True)
    seasonality_prior_scale = trial.suggest_float("seasonality_prior_scale", 1, 20, log=True)
    seasonality_mode = trial.suggest_categorical("seasonality_mode", ["additive", "multiplicative"])
    
    model = Prophet(
        changepoint_prior_scale=changepoint_prior_scale,
        seasonality_prior_scale=seasonality_prior_scale,
        seasonality_mode=seasonality_mode,
        yearly_seasonality=True,   
        weekly_seasonality=False, 
        daily_seasonality=False    
    )

    model.fit(prophet_df)

    df_cv = cross_validation(
        model,
        initial='365 days',
        period='90 days',
        horizon='30 days'
        )
    df_perf = performance_metrics(df_cv)

    rmse = df_perf['rmse'].mean()
    return rmse

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30, show_progress_bar=False)   # try 30 different parameter sets

print("Best parameters:", study.best_params)
print("Best RMSE:", study.best_value)
# Out:
# [I 2025-09-03 13:09:36,426] A new study created in memory with name: no-name-3be3d6c2-5b5f-4288-ba79-b579f0a06567
# 13:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:36 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:36 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:36 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 19.39it/s]
# [I 2025-09-03 13:09:36,630] Trial 0 finished with value: 0.22273783778795864 and parameters: {'changepoint_prior_scale': 0.0025191400197472342, 'seasonality_prior_scale': 1.3199369038308713, 'seasonality_mode': 'additive'}. Best is trial 0 with value: 0.22273783778795864.
# 13:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:36 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:36 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:36 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 19.16it/s]
# [I 2025-09-03 13:09:36,791] Trial 1 finished with value: 0.24824724658398573 and parameters: {'changepoint_prior_scale': 0.0015585330411518297, 'seasonality_prior_scale': 12.461161137059568, 'seasonality_mode': 'multiplicative'}. Best is trial 0 with value: 0.22273783778795864.
# 13:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:36 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 1/2 [00:00<00:00,  5.47it/s]13:09:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00,  5.93it/s]
# [I 2025-09-03 13:09:37,295] Trial 2 finished with value: 0.3718762272424144 and parameters: {'changepoint_prior_scale': 0.40341309793388225, 'seasonality_prior_scale': 6.531877199183697, 'seasonality_mode': 'additive'}. Best is trial 0 with value: 0.22273783778795864.
# 13:09:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 15.08it/s]
# [I 2025-09-03 13:09:37,525] Trial 3 finished with value: 0.14596825481004247 and parameters: {'changepoint_prior_scale': 0.045114009100551876, 'seasonality_prior_scale': 8.285604620466367, 'seasonality_mode': 'additive'}. Best is trial 3 with value: 0.14596825481004247.
# 13:09:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 15.39it/s]
# [I 2025-09-03 13:09:37,727] Trial 4 finished with value: 0.13160226499755961 and parameters: {'changepoint_prior_scale': 0.007610038296372708, 'seasonality_prior_scale': 2.98459598692762, 'seasonality_mode': 'additive'}. Best is trial 4 with value: 0.13160226499755961.
# 13:09:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:37 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 1/2 [00:00<00:00,  7.15it/s]13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00,  6.81it/s]
# [I 2025-09-03 13:09:38,242] Trial 5 finished with value: 0.37412852057032586 and parameters: {'changepoint_prior_scale': 0.36232823824371624, 'seasonality_prior_scale': 1.181989760549249, 'seasonality_mode': 'additive'}. Best is trial 4 with value: 0.13160226499755961.
# 13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 19.59it/s]
# [I 2025-09-03 13:09:38,417] Trial 6 finished with value: 0.15609806057309208 and parameters: {'changepoint_prior_scale': 0.0061109290001665935, 'seasonality_prior_scale': 7.233775427040884, 'seasonality_mode': 'additive'}. Best is trial 4 with value: 0.13160226499755961.
# 13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 1/2 [00:00<00:00,  7.59it/s]13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00,  8.32it/s]
# [I 2025-09-03 13:09:38,770] Trial 7 finished with value: 0.3058212858784709 and parameters: {'changepoint_prior_scale': 0.10418414864509279, 'seasonality_prior_scale': 1.4054339606078063, 'seasonality_mode': 'additive'}. Best is trial 4 with value: 0.13160226499755961.
# 13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 20.26it/s]
# [I 2025-09-03 13:09:38,933] Trial 8 finished with value: 0.22273080623613992 and parameters: {'changepoint_prior_scale': 0.002501537371231575, 'seasonality_prior_scale': 3.1810187112276727, 'seasonality_mode': 'additive'}. Best is trial 4 with value: 0.13160226499755961.
# 13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:38 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 18.42it/s]
# [I 2025-09-03 13:09:39,102] Trial 9 finished with value: 0.17254258683250787 and parameters: {'changepoint_prior_scale': 0.0046872237055307405, 'seasonality_prior_scale': 18.686260026609922, 'seasonality_mode': 'multiplicative'}. Best is trial 4 with value: 0.13160226499755961.
# 13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 18.58it/s]
# [I 2025-09-03 13:09:39,280] Trial 10 finished with value: 0.09134270874517128 and parameters: {'changepoint_prior_scale': 0.014185707227996164, 'seasonality_prior_scale': 3.4667741552364166, 'seasonality_mode': 'multiplicative'}. Best is trial 10 with value: 0.09134270874517128.
# 13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 15.60it/s]
# [I 2025-09-03 13:09:39,488] Trial 11 finished with value: 0.0910096135018829 and parameters: {'changepoint_prior_scale': 0.014666041708915898, 'seasonality_prior_scale': 3.5868474557910046, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 16.38it/s]
# [I 2025-09-03 13:09:39,685] Trial 12 finished with value: 0.09556268362807865 and parameters: {'changepoint_prior_scale': 0.0215417660634123, 'seasonality_prior_scale': 2.507808987808093, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 16.67it/s]
# [I 2025-09-03 13:09:39,885] Trial 13 finished with value: 0.09420193784745251 and parameters: {'changepoint_prior_scale': 0.020289614039765598, 'seasonality_prior_scale': 4.250740002295654, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:39 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 12.03it/s]
# [I 2025-09-03 13:09:40,147] Trial 14 finished with value: 0.20750448555517773 and parameters: {'changepoint_prior_scale': 0.0658484073676534, 'seasonality_prior_scale': 2.3703669594883334, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 15.64it/s]
# [I 2025-09-03 13:09:40,347] Trial 15 finished with value: 0.10020985228020204 and parameters: {'changepoint_prior_scale': 0.0107875864449611, 'seasonality_prior_scale': 4.974101005265614, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 17.53it/s]
# [I 2025-09-03 13:09:40,574] Trial 16 finished with value: 0.11562337905559221 and parameters: {'changepoint_prior_scale': 0.03404047976423119, 'seasonality_prior_scale': 1.9612431096188572, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 16.46it/s]
# [I 2025-09-03 13:09:40,763] Trial 17 finished with value: 0.09208590286012137 and parameters: {'changepoint_prior_scale': 0.014096602877840519, 'seasonality_prior_scale': 4.038035843717157, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:40 - cmdstanpy - INFO - Chain [1] done processing
#  50%|█████     | 1/2 [00:00<00:00,  7.89it/s]13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00,  7.17it/s]
# [I 2025-09-03 13:09:41,156] Trial 18 finished with value: 0.36601375395979435 and parameters: {'changepoint_prior_scale': 0.14122212330045894, 'seasonality_prior_scale': 9.681894363902982, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 18.94it/s]
# [I 2025-09-03 13:09:41,323] Trial 19 finished with value: 0.24896652092592683 and parameters: {'changepoint_prior_scale': 0.001068149614040464, 'seasonality_prior_scale': 5.246264197992659, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 18.29it/s]
# [I 2025-09-03 13:09:41,495] Trial 20 finished with value: 0.17743188555126715 and parameters: {'changepoint_prior_scale': 0.0041189884277929, 'seasonality_prior_scale': 1.8597797706876293, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 18.98it/s]
# [I 2025-09-03 13:09:41,664] Trial 21 finished with value: 0.09181807466657442 and parameters: {'changepoint_prior_scale': 0.011785425086740065, 'seasonality_prior_scale': 3.7573798154398386, 'seasonality_mode': 'multiplicative'}. Best is trial 11 with value: 0.0910096135018829.
# 13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 17.41it/s]
# [I 2025-09-03 13:09:41,855] Trial 22 finished with value: 0.09056481207493536 and parameters: {'changepoint_prior_scale': 0.012645498677468493, 'seasonality_prior_scale': 3.3708425689393136, 'seasonality_mode': 'multiplicative'}. Best is trial 22 with value: 0.09056481207493536.
# 13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 14.46it/s]
# [I 2025-09-03 13:09:42,076] Trial 23 finished with value: 0.13513303167675927 and parameters: {'changepoint_prior_scale': 0.033639644347867606, 'seasonality_prior_scale': 3.0648356643794514, 'seasonality_mode': 'multiplicative'}. Best is trial 22 with value: 0.09056481207493536.
# 13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 14.21it/s]
# [I 2025-09-03 13:09:42,289] Trial 24 finished with value: 0.09168539433156747 and parameters: {'changepoint_prior_scale': 0.016997733921621808, 'seasonality_prior_scale': 1.814697492243613, 'seasonality_mode': 'multiplicative'}. Best is trial 22 with value: 0.09056481207493536.
# 13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 18.73it/s]
# [I 2025-09-03 13:09:42,463] Trial 25 finished with value: 0.10376015855542323 and parameters: {'changepoint_prior_scale': 0.009788529990113476, 'seasonality_prior_scale': 5.295437066503787, 'seasonality_mode': 'multiplicative'}. Best is trial 22 with value: 0.09056481207493536.
# 13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 17.04it/s]
# [I 2025-09-03 13:09:42,653] Trial 26 finished with value: 0.10859159048257407 and parameters: {'changepoint_prior_scale': 0.0278233615966639, 'seasonality_prior_scale': 2.6229355050409047, 'seasonality_mode': 'multiplicative'}. Best is trial 22 with value: 0.09056481207493536.
# 13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 15.94it/s]
# [I 2025-09-03 13:09:42,876] Trial 27 finished with value: 0.171690776253221 and parameters: {'changepoint_prior_scale': 0.050934860626806674, 'seasonality_prior_scale': 3.6871675656619467, 'seasonality_mode': 'multiplicative'}. Best is trial 22 with value: 0.09056481207493536.
# 13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:43 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 20.81it/s]
# [I 2025-09-03 13:09:43,045] Trial 28 finished with value: 0.16438731475848448 and parameters: {'changepoint_prior_scale': 0.003808359346381951, 'seasonality_prior_scale': 6.101522787383669, 'seasonality_mode': 'multiplicative'}. Best is trial 22 with value: 0.09056481207493536.
# 13:09:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:43 - cmdstanpy - INFO - Chain [1] done processing
# Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/2 [00:00<?, ?it/s]13:09:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:43 - cmdstanpy - INFO - Chain [1] done processing
# 13:09:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:09:43 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 2/2 [00:00<00:00, 21.15it/s]
# [I 2025-09-03 13:09:43,195] Trial 29 finished with value: 0.2402570139919008 and parameters: {'changepoint_prior_scale': 0.0026233346021162568, 'seasonality_prior_scale': 2.3479338522371163, 'seasonality_mode': 'multiplicative'}. Best is trial 22 with value: 0.09056481207493536.
# Best parameters: {'changepoint_prior_scale': 0.012645498677468493, 'seasonality_prior_scale': 3.3708425689393136, 'seasonality_mode': 'multiplicative'}
# Best RMSE: 0.09056481207493536

# %% [markdown]
# 0.0903839449495678

# %%
best_params = study.best_params

best_model = Prophet(
    changepoint_prior_scale=best_params["changepoint_prior_scale"],
    seasonality_prior_scale=best_params["seasonality_prior_scale"],
    seasonality_mode=best_params["seasonality_mode"],
    yearly_seasonality=True,
    weekly_seasonality=False,
    daily_seasonality=False
)

best_model.fit(prophet_df)
# Out:
# 12:19:18 - cmdstanpy - INFO - Chain [1] start processing
# 12:19:18 - cmdstanpy - INFO - Chain [1] done processing

# %%
train_df.shape, valid_df.shape, test_df.shape,
# Out:
# ((140521, 9), (6639, 9), (3677, 9))

# %%
train_df.groupby(['Product_Type', 'Market']).size().reset_index().shape
# Out:
# (293, 3)

# %%
d = train_df.groupby(['Product_Type', 'Market']).size().reset_index()

# %%
d[d['Product_Type'] == 'Bitter gourd|Other|FAQ']
# Out:
#               Product_Type         Market    0
# 88  Bitter gourd|Other|FAQ  Kothamangalam  561
# 89  Bitter gourd|Other|FAQ        Piravam  525

# %%
d.iloc[146]
# Out:
# Product_Type    Coriander(Leaves)|Other|FAQ
# Market                              Piravam
# 0                                       115
# Name: 146, dtype: object

# %%
d[0].min()
# Out:
# np.int64(107)

# %%
train_df.head()
# Out:
#                 Product_Type   Commodity           Variety_Type Arrival_Date  \
# 0  Alsandikai|Alsandikai|FAQ  Alsandikai  Alsandikai|Alsandikai   2023-12-13
# 1  Alsandikai|Alsandikai|FAQ  Alsandikai  Alsandikai|Alsandikai   2023-12-14
# 2  Alsandikai|Alsandikai|FAQ  Alsandikai  Alsandikai|Alsandikai   2023-12-16
# 3  Alsandikai|Alsandikai|FAQ  Alsandikai  Alsandikai|Alsandikai   2023-12-18
# 4  Alsandikai|Alsandikai|FAQ  Alsandikai  Alsandikai|Alsandikai   2023-12-19
#
#           Market  Is_VFPCK  Season  Year  log_Modal_Price
# 0  North Paravur     False  Winter  2023         8.556606
# 1  North Paravur     False  Winter  2023         8.732466
# 2  North Paravur     False  Winter  2023         8.476580
# 3  North Paravur     False  Winter  2023         8.160804
# 4  North Paravur     False  Winter  2023         8.612685
